# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.svm import SVC
from sklearn.svm import SVR

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("C:/Users/ADHITHYA/Downloads/data_mobile_price_range.csv")

print(df.head())
print(df.shape)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
x = df.drop('price_range', axis=1)
y = df['price_range']

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# %%
scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
svm_classifier = SVC(
    kernel='rbf',
    C=1,
    gamma='scale'
)

svm_classifier.fit(x_train_scaled, y_train)
# Out:
# SVC(C=1)

# %%
y_pred_class = svm_classifier.predict(x_test_scaled)

# %%
print("SVM Classification Accuracy:")
print(accuracy_score(y_test, y_pred_class))

print("Classification Report:")
print(classification_report(y_test, y_pred_class))
# Out:
# SVM Classification Accuracy:
# 0.8925
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       105
#            1       0.80      0.89      0.84        91
#            2       0.84      0.82      0.83        92
#            3       0.96      0.92      0.94       112
#
#     accuracy                           0.89       400
#    macro avg       0.89      0.89      0.89       400
# weighted avg       0.90      0.89      0.89       400

# %%
svm_regressor = SVR(
    kernel='rbf',
    C=100,
    gamma=0.1,
    epsilon=0.1
)

svm_regressor.fit(x_train_scaled, y_train)
# Out:
# SVR(C=100, gamma=0.1)

# %%
y_pred_reg = svm_regressor.predict(x_test_scaled)

# %%
mae = mean_absolute_error(y_test, y_pred_reg)
mse = mean_squared_error(y_test, y_pred_reg)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred_reg)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R2 Score:", r2)
# Out:
# Mean Absolute Error: 0.3295956685325682
# Mean Squared Error: 0.16580665890426982
# Root Mean Squared Error: 0.407193638094052
# R2 Score: 0.8757298590274305

# %%
new_data = [[842,0,2.2,0,1,0,7,0.6,188,2,2,20,756,2549,9,7,19,0,0,1]]

new_data_scaled = scaler.transform(new_data)

prediction = svm_classifier.predict(new_data_scaled)

print("Predicted Price Range:", prediction[0])
# Out:
# Predicted Price Range: 1
# C:\Users\ADHITHYA\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
reg_prediction = svm_regressor.predict(new_data_scaled)

print("Predicted Regression Value:", reg_prediction[0])
# Out:
# Predicted Regression Value: 1.1000329751871094

# %%
comparison_df = pd.DataFrame({
    'Model': ['SVM Classifier', 'SVR Regressor'],
    'Accuracy': [accuracy_score(y_test, y_pred_class), 'Not Applicable'],
    'MAE': ['Not Applicable', mean_absolute_error(y_test, y_pred_reg)],
    'MSE': ['Not Applicable', mean_squared_error(y_test, y_pred_reg)],
    'RMSE': ['Not Applicable', np.sqrt(mean_squared_error(y_test, y_pred_reg))],
    'R2 Score': ['Not Applicable', r2_score(y_test, y_pred_reg)]
})

print(comparison_df)
# Out:
#             Model        Accuracy             MAE             MSE  \
# 0  SVM Classifier          0.8925  Not Applicable  Not Applicable
# 1   SVR Regressor  Not Applicable        0.329596        0.165807
#
#              RMSE        R2 Score
# 0  Not Applicable  Not Applicable
# 1        0.407194         0.87573
